# %% [markdown]
# # MMA 867 - Individual Assignment - 3
#
# ## Predicting COVID-19 cases using TimeSeries Analysis
#
# ## By Gopala Goyal - 20254605
#
# > As a part of the assignment, we would be working on the Covid dataset and forcasting the New Covid-19 Cases in the US using timeseries analysis

# %%
#Import the required libraries
import pmdarima as pm
import pandas as pd
import numpy as np
import matplotlib as mplt
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.tsa.arima_model import ARIMA
from scipy.stats import boxcox
from datetime import datetime, timedelta
# %matplotlib inline

# %% [markdown]
# ### Data Exploration

# %%
#Load the dataset
df_covid=pd.read_csv("owid-covid-data.csv")

# %%
#Check the null values in the dataset
df_covid.isna().sum()
# Out:
# iso_code                           0
# continent                       5344
# location                           0
# date                               0
# total_cases                     5732
#                                ...
# handwashing_facilities         64786
# hospital_beds_per_thousand     22621
# life_expectancy                 6003
# human_development_index        13160
# excess_mortality              112804
# Length: 62, dtype: int64

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116807 entries, 0 to 116806
# Data columns (total 62 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               116807 non-null  object
#  1   continent                              111463 non-null  object
#  2   location                               116807 non-null  object
#  3   date                                   116807 non-null  object
#  4   total_cases                            111075 non-null  float64
#  5   new_cases                              111072 non-null  float64
#  6   new_cases_smoothed                     110057 non-null  float64
#  7   total_deaths                           100421 non-null  float64
#  8   new_deaths                             100576 non-null  float64
#  9   new_deaths_smoothed                    110057 non-null  float64
#  10  total_cases_per_million                110489 non-null  float64
#  11  new_cases_per_million                  110486 non-null  float64
#  12  new_cases_smoothed_per_million         109476 non-null  float64
#  13  total_deaths_per_million               99848 non-null   float64
#  14  new_deaths_per_million                 100003 non-null  float64
#  15  new_deaths_smoothed_per_million        109476 non-null  float64
#  16  reproduction_rate                      94064 non-null   float64
#  17  icu_patients                           12638 non-null   float64
#  18  icu_patients_per_million               12638 non-null   float64
#  19  hosp_patients                          15101 non-null   float64
#  20  hosp_patients_per_million              15101 non-null   float64
#  21  weekly_icu_admissions                  1143 non-null    float64
#  22  weekly_icu_admissions_per_million      1143 non-null    float64
#  23  weekly_hosp_admissions                 2029 non-null    float64
#  24  weekly_hosp_admissions_per_million     2029 non-null    float64
#  25  new_tests                              50821 non-null   float64
#  26  total_tests                            50663 non-null   float64
#  27  total_tests_per_thousand               50663 non-null   float64
#  28  new_tests_per_thousand                 50821 non-null   float64
#  29  new_tests_smoothed                     60192 non-null   float64
#  30  new_tests_smoothed_per_thousand        60192 non-null   float64
#  31  positive_rate                          56924 non-null   float64
#  32  tests_per_case                         56301 non-null   float64
#  33  tests_units                            62067 non-null   object
#  34  total_vaccinations                     25444 non-null   float64
#  35  people_vaccinated                      24340 non-null   float64
#  36  people_fully_vaccinated                21304 non-null   float64
#  37  total_boosters                         1914 non-null    float64
#  38  new_vaccinations                       21060 non-null   float64
#  39  new_vaccinations_smoothed              45407 non-null   float64
#  40  total_vaccinations_per_hundred         25444 non-null   float64
#  41  people_vaccinated_per_hundred          24340 non-null   float64
#  42  people_fully_vaccinated_per_hundred    21304 non-null   float64
#  43  total_boosters_per_hundred             1914 non-null    float64
#  44  new_vaccinations_smoothed_per_million  45407 non-null   float64
#  45  stringency_index                       96543 non-null   float64
#  46  population                             116007 non-null  float64
#  47  population_density                     108004 non-null  float64
#  48  median_age                             103262 non-null  float64
#  49  aged_65_older                          102112 non-null  float64
#  50  aged_70_older                          102695 non-null  float64
#  51  gdp_per_capita                         103835 non-null  float64
#  52  extreme_poverty                        69745 non-null   float64
#  53  cardiovasc_death_rate                  103553 non-null  float64
#  54  diabetes_prevalence                    106682 non-null  float64
#  55  female_smokers                         80881 non-null   float64
#  56  male_smokers                           79705 non-null   float64
#  57  handwashing_facilities                 52021 non-null   float64
#  58  hospital_beds_per_thousand             94186 non-null   float64
#  59  life_expectancy                        110804 non-null  float64
#  60  human_development_index                103647 non-null  float64
#  61  excess_mortality                       4003 non-null    float64
# dtypes: float64(57), object(5)
# memory usage: 55.3+ MB

# %%
#Checking the statistics of various variables
df_covid.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.110750e+05  111072.000000       110057.000000  1.004210e+05
# mean   1.354885e+06    6423.650911         6438.922915  3.480560e+04
# std    9.104489e+06   39317.057192        38895.755497  2.075685e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.825000e+03       3.000000            8.857000  6.400000e+01
# 50%    1.863900e+04      89.000000          110.000000  5.630000e+02
# 75%    1.991870e+05     902.000000          951.857000  4.867000e+03
# max    2.258059e+08  905932.000000       826340.429000  4.648435e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  100576.000000        110057.000000            110489.000000
# mean      145.968849           132.702924             16703.178299
# std       796.005158           743.966548             28912.479820
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.000000               319.769000
# 50%         2.000000             1.571000              2494.790000
# 75%        18.000000            15.429000             19434.909000
# max     17976.000000         14722.714000            208199.373000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          110486.000000                   109476.000000
# mean               81.513726                       81.479976
# std               190.090310                      161.294316
# min             -3125.829000                     -272.971000
# 25%                 0.274000                        1.488000
# 50%                10.235500                       13.932000
# 75%                79.054750                       88.076000
# max              8620.690000                     3385.473000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count              99848.000000  ...     69745.000000          103553.000000
# mean                 353.666743  ...        13.465236             259.119244
# std                  608.001663  ...        19.978299             119.279548
# min                    0.001000  ...         0.100000              79.370000
# 25%                    9.705500  ...         0.600000             168.711000
# 50%                   63.792000  ...         2.200000             243.811000
# 75%                  422.042250  ...        21.200000             329.942000
# max                 5960.536000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count        106682.000000    80881.000000  79705.000000
# mean              8.001839       10.596205     32.731274
# std               4.259676       10.506179     13.499370
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.600000
# 50%               7.110000        6.300000     31.400000
# 75%              10.080000       19.300000     41.100000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            52021.000000                94186.000000    110804.000000
# mean                50.756233                    3.024659        73.258880
# std                 31.754145                    2.453891         7.544932
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.920000
# 50%                 49.839000                    2.400000        74.620000
# 75%                 82.502000                    3.861000        78.740000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality
# count            103647.000000       4003.000000
# mean                  0.726673         18.064269
# std                   0.150256         35.095659
# min                   0.394000        -95.590000
# 25%                   0.602000          0.645000
# 50%                   0.744000          7.640000
# 75%                   0.848000         23.595000
# max                   0.957000        410.900000
#
# [8 rows x 57 columns]

# %%
#In Python to ease out the process of plotting and doing the TimeSeries Analysis, we make the Date field as the index of the dataframe
df_covid.index = pd.to_datetime(df_covid.date)

# %%
df_covid.head()
# Out:
#            iso_code continent     location        date  total_cases  \
# date
# 2020-02-24      AFG      Asia  Afghanistan  2020-02-24          5.0
# 2020-02-25      AFG      Asia  Afghanistan  2020-02-25          5.0
# 2020-02-26      AFG      Asia  Afghanistan  2020-02-26          5.0
# 2020-02-27      AFG      Asia  Afghanistan  2020-02-27          5.0
# 2020-02-28      AFG      Asia  Afghanistan  2020-02-28          5.0
#
#             new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# date
# 2020-02-24        5.0                 NaN           NaN         NaN
# 2020-02-25        0.0                 NaN           NaN         NaN
# 2020-02-26        0.0                 NaN           NaN         NaN
# 2020-02-27        0.0                 NaN           NaN         NaN
# 2020-02-28        0.0                 NaN           NaN         NaN
#
#             new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# date                             ...
# 2020-02-24                  NaN  ...              NaN                597.029
# 2020-02-25                  NaN  ...              NaN                597.029
# 2020-02-26                  NaN  ...              NaN                597.029
# 2020-02-27                  NaN  ...              NaN                597.029
# 2020-02-28                  NaN  ...              NaN                597.029
#
#             diabetes_prevalence  female_smokers  male_smokers  \
# date
# 2020-02-24                 9.59             NaN           NaN
# 2020-02-25                 9.59             NaN           NaN
# 2020-02-26                 9.59             NaN           NaN
# 2020-02-27                 9.59             NaN           NaN
# 2020-02-28                 9.59             NaN           NaN
#
#             handwashing_facilities  hospital_beds_per_thousand  \
# date
# 2020-02-24                  37.746                         0.5
# 2020-02-25                  37.746                         0.5
# 2020-02-26                  37.746                         0.5
# 2020-02-27                  37.746                         0.5
# 2020-02-28                  37.746                         0.5
#
#             life_expectancy  human_development_index  excess_mortality
# date
# 2020-02-24            64.83                    0.511               NaN
# 2020-02-25            64.83                    0.511               NaN
# 2020-02-26            64.83                    0.511               NaN
# 2020-02-27            64.83                    0.511               NaN
# 2020-02-28            64.83                    0.511               NaN
#
# [5 rows x 62 columns]

# %%
#As per the assignment, we need to forecase the cases for Canada, so we created a new dataframe which is a subset of the whole dataframe loaded above
df_covid_can = df_covid[df_covid.iso_code == 'CAN']

# %%
df_covid_can.shape
# Out:
# (598, 62)

# %%
df_covid_can.head()
# Out:
#            iso_code      continent location        date  total_cases  \
# date
# 2020-01-26      CAN  North America   Canada  2020-01-26          1.0
# 2020-01-27      CAN  North America   Canada  2020-01-27          1.0
# 2020-01-28      CAN  North America   Canada  2020-01-28          2.0
# 2020-01-29      CAN  North America   Canada  2020-01-29          2.0
# 2020-01-30      CAN  North America   Canada  2020-01-30          2.0
#
#             new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# date
# 2020-01-26        1.0                 NaN           NaN         NaN
# 2020-01-27        0.0                 NaN           NaN         NaN
# 2020-01-28        1.0                 NaN           NaN         NaN
# 2020-01-29        0.0                 NaN           NaN         NaN
# 2020-01-30        0.0                 NaN           NaN         NaN
#
#             new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# date                             ...
# 2020-01-26                  NaN  ...              0.5                105.599
# 2020-01-27                  NaN  ...              0.5                105.599
# 2020-01-28                  NaN  ...              0.5                105.599
# 2020-01-29                  NaN  ...              0.5                105.599
# 2020-01-30                  NaN  ...              0.5                105.599
#
#             diabetes_prevalence  female_smokers  male_smokers  \
# date
# 2020-01-26                 7.37            12.0          16.6
# 2020-01-27                 7.37            12.0          16.6
# 2020-01-28                 7.37            12.0          16.6
# 2020-01-29                 7.37            12.0          16.6
# 2020-01-30                 7.37            12.0          16.6
#
#             handwashing_facilities  hospital_beds_per_thousand  \
# date
# 2020-01-26                     NaN                         2.5
# 2020-01-27                     NaN                         2.5
# 2020-01-28                     NaN                         2.5
# 2020-01-29                     NaN                         2.5
# 2020-01-30                     NaN                         2.5
#
#             life_expectancy  human_development_index  excess_mortality
# date
# 2020-01-26            82.43                    0.929               4.2
# 2020-01-27            82.43                    0.929               NaN
# 2020-01-28            82.43                    0.929               NaN
# 2020-01-29            82.43                    0.929               NaN
# 2020-01-30            82.43                    0.929               NaN
#
# [5 rows x 62 columns]

# %%
df_covid_can = df_covid_can.iloc[40:]

# %%
#plot the Canada Covid new cases TS data

plt.figure(figsize = (20,10))
fig = plt.figure(1)
plt.plot(df_covid_can['new_cases'])

# %%
#plot the Canada Covid Stringency index TS data

plt.figure(figsize = (20,10))
fig = plt.figure(1)
plt.plot(df_covid_can['stringency_index'])

# %%
#plot the Canada Covid vaccinations TS data

plt.figure(figsize = (20,10))
fig = plt.figure(1)
plt.plot(df_covid_can['total_vaccinations'])

# %% [markdown]
# ### Checking Stationarity of data
#
# > 1. Using Rolling Statistics
#
# > 2. Using the Duckey Fuller test

# %%
rolling_mean = df_covid_can['new_cases'].rolling(12).mean()
rolling_std = df_covid_can['new_cases'].rolling(12).std()

plt.figure(figsize = (15,6))
orig = plt.plot(df_covid_can['new_cases'], color = 'blue', label='Original')
rol_mean = plt.plot(rolling_mean, color = 'red', label='Mean')
rol_std = plt.plot(rolling_std, color = 'black', label='Std')

plt.legend(loc = 'best')
plt.title('Rolling mean vs Standard Deviation vs Original TS')
plt.show()

# %% [markdown]
# > According to the above plot, we see that the variance/standard deviation increases with the mean
#
# > The data has a trends as we can see the fluctuations and hence the data is **non-stationary**
#
# > The data has seasonality as there are certain repeating spikes/pattern on some days like on the weekdays

# %% [markdown]
# ## Pre-Processing

# %%
#To make the data stationary, we will try to make the data as normal using log-transformation

covid_can_log = np.log(df_covid_can['new_cases'])

# %%
plt.figure(figsize = (15,6))
plt.plot(covid_can_log, color = 'blue', label='Log')
plt.legend(loc = 'best')
plt.title("Log Transformation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
box_cox_data, box_cox_lambda = boxcox(df_covid_can['new_cases'])

# %%
print(box_cox_lambda)
# Out:
# 0.2440474453877445

# %%
plt.figure(figsize = (15,6))
plt.plot(box_cox_data, color = 'red', label='BoxCox')
plt.legend(loc = 'best')
plt.title("Box Cox Transformation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# > Box Cox transformation did not perform well on hte data in comparison to the log transformation hence we will be using the log transformation to perform the forecasting

# %% [markdown]
# ### Applying seasonal decomposition

# %% [markdown]
# > Here, we would be separating the time series into different components and checking what is contributing more towards the timeseries stationarity

# %%
decomp = seasonal_decompose(covid_can_log, period = 7, model = 'multiplicative')

# %%
trend = decomp.trend
seasonal = decomp.seasonal
residual = decomp.resid

# %%
plt.figure(figsize = (20,10))
fig = plt.figure(1)

plt.subplot(411)
plt.plot(covid_can_log, label='Original')
plt.legend(loc = 'best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc = 'best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc = 'best')
plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc = 'best')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# > According to the above graph, it is evident that there is a constant seasonality in the data
#
# > The trend is driving the TimeSeries and it is because of the trend that we can see the non-stationarity
#
# > We would now perform differencing on the trend to make the TimeSeries stationary (and detect the seasonality????)

# %%
#Calculate the difference
covid_can_log_diff = covid_can_log - covid_can_log.shift()

#Calculate difference statistics
roll_mean_diff = covid_can_log_diff.rolling(12).mean()
roll_std_diff = covid_can_log_diff.rolling(12).std()

#plot the difference

plt.figure(figsize = (15,6))

plt.plot(covid_can_log_diff, color = 'blue', label='Original')
rol_mean_diff = plt.plot(roll_mean_diff, color = 'red', label='Mean')
rol_std_diff = plt.plot(roll_std_diff, color = 'black', label='Std')

plt.legend(loc = 'best')
plt.title("Difference plots")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Plotting ACF & PACF for Differenced TimeSeries

# %%
lag_acf = acf(covid_can_log_diff, nlags = 7)
lag_pacf = pacf(covid_can_log_diff, nlags = 7)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:671: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning,

# %%
import statsmodels.api as sm

fig = plt.figure(figsize = (15,6))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(covid_can_log_diff.dropna(),lags = 25, ax = ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(covid_can_log_diff.dropna(),lags = 25, ax = ax2)

# %%
plt.figure(figsize = (15,6))
model = ARIMA(covid_can_log, order = (2,1,2))
results = model.fit(disp=1)
plt.plot(covid_can_log_diff)
plt.plot(results.fittedvalues, color = 'red')
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /Users/apple/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /Users/apple/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
model = pm.auto_arima(df_covid_can['new_cases'],
                      test='adf',      
                      m=1,             
                      d=None,          
                      seasonal=True,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=9180.163, Time=0.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=9537.161, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=9409.020, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=9264.639, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=9535.180, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=9263.358, Time=0.67 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=9236.694, Time=0.37 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=9184.853, Time=1.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=9262.952, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=9180.732, Time=0.93 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=9239.197, Time=0.20 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=9178.470, Time=0.53 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=9262.564, Time=0.30 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=9234.977, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=9181.551, Time=0.48 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=9176.379, Time=0.76 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=9179.056, Time=0.32 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=1.24 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=inf, Time=1.48 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=9181.056, Time=0.64 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=9163.439, Time=1.50 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=9144.251, Time=1.78 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=9164.457, Time=1.05 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=9138.297, Time=1.70 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=9164.783, Time=1.03 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=9142.829, Time=1.79 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=9135.895, Time=2.27 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=9159.346, Time=0.90 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=9138.973, Time=2.19 sec
#
# Best model:  ARIMA(4,1,5)(0,0,0)[0]
# Total fit time: 27.350 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  558
# Model:               SARIMAX(4, 1, 5)   Log Likelihood               -4557.948
# Date:                Wed, 15 Sep 2021   AIC                           9135.895
# Time:                        15:54:03   BIC                           9179.121
# Sample:                             0   HQIC                          9152.778
#                                 - 558
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6990      0.084      8.307      0.000       0.534       0.864
# ar.L2         -1.0854      0.035    -30.791      0.000      -1.154      -1.016
# ar.L3          0.8619      0.062     13.836      0.000       0.740       0.984
# ar.L4         -0.5965      0.059    -10.075      0.000      -0.713      -0.480
# ma.L1         -1.6005      0.097    -16.461      0.000      -1.791      -1.410
# ma.L2          1.6673      0.120     13.851      0.000       1.431       1.903
# ma.L3         -1.6288      0.103    -15.750      0.000      -1.832      -1.426
# ma.L4          1.2957      0.113     11.493      0.000       1.075       1.517
# ma.L5         -0.3425      0.074     -4.632      0.000      -0.487      -0.198
# sigma2      8.007e+05   2.56e+04     31.223      0.000     7.5e+05    8.51e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):              3203.36
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):              30.31   Skew:                             1.45
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
new_df_covid_can = df_covid_can['new_cases'].reset_index()

# %%
new_df_covid_can
# Out:
#           date  new_cases
# 0   2020-03-06       14.0
# 1   2020-03-07        4.0
# 2   2020-03-08       10.0
# 3   2020-03-09       14.0
# 4   2020-03-10        4.0
# ..         ...        ...
# 553 2021-09-10     4599.0
# 554 2021-09-11      913.0
# 555 2021-09-12     2774.0
# 556 2021-09-13     9288.0
# 557 2021-09-14     4014.0
#
# [558 rows x 2 columns]

# %%
# Forecast
n_periods = 14
freq= 'D'
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(date, periods=14)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize = (30,15))
plt.plot(df_covid_can['new_cases'])
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of ...")
plt.show()
